# %%
import pystripe
# Out:
# /home/jswaney/anaconda3/envs/pystripe/lib/python3.6/site-packages/tifffile/tifffile.py:7685: UserWarning: No module named 'tifffile._tifffile'
#   Functionality might be degraded or be slow.
#
#   warnings.warn('%s%s' % (e, warn))

# %%
img_path = '/home/jswaney/pystripe/scripts/img.raw'
img = pystripe.imread(img_path)
img.shape
# Out:
# (2048, 2048)

# %%
import matplotlib.pyplot as plt
plt.imshow(img, clim=[0, 1000])
plt.show()

# %%
destriped = pystripe.filter_streaks(img, sigma=10, level=6, wavelet='db10')
plt.imshow(destriped, clim=[0, 1000])
plt.show()
